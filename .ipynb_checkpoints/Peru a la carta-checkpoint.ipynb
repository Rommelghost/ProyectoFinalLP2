# %% [markdown]
# ## Call de vuelos del API de Amadeus
#
# ![Logo Amadeus](https://publitur.com/wp-content/uploads/2019/12/amadeus_OK.jpg)

# %%
pip install amadeus
# Out:
# Requirement already satisfied: amadeus in c:\users\romme\anaconda3\lib\site-packages (9.0.0)Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as ptl
import seaborn as sns
from urllib.request import urlopen
from bs4 import BeautifulSoup as soup
import requests
import json
from amadeus import Client, ResponseError

# %%
# Configuración de nuestro usuario de Amadeus
amadeus = Client(
    client_id='OvHfoJ8hyt7lzWXAAnCrxSf7dJTT9XTP',
    client_secret='ZJ6yBQd1nhdhxGgG'
)

# Buscamos las ofertas de vuelos con el API de Amadeus
try:
    vuelos = amadeus.shopping.flight_offers_search.get(
        originLocationCode='EZE',
        destinationLocationCode='LIM',
        departureDate='2024-01-20',
        returnDate='2024-01-25',
        currencyCode='PEN',
        adults=1
    )

# Extraemos la lista de ofertas de vuelos desde la respuesta (Atributo "Vuelos")
    oferta_vuelos = vuelos.data

# Nos aseguramos que hay ofertas en el la respuesta del atributo "Vuelos"
    if 'offerItems' in oferta_vuelos[0]:
        
# Ordenamos las ofertas de vuelos por precio total de menor a mayor
        sorted_oferta_vuelos = sorted(oferta_vuelos, key=lambda x: float(x['offerItems'][0]['price']['total']))
    else:
        
# Si la estructura es diferente, ordenamos por el precio total directamente
        sorted_oferta_vuelos = sorted(oferta_vuelos, key=lambda x: float(x['price']['total']))

# Obtenemo los vuelos más económicos según la solicitud
    top_oferta_vuelos = sorted_oferta_vuelos[:5]

# Convertimos la respuesta a formato JSON
    json_vuelos = json.loads(json.dumps(top_oferta_vuelos))

# Convierte el JSON a un DataFrame de pandas
    df_vuelos = pd.json_normalize(json_vuelos)

except ResponseError as error:
    print(error)

# %%
#Visualizamos nuestra respuesta en formato JSON
json_vuelos
# Out:
# [{'type': 'flight-offer',
#   'id': '1',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'lastTicketingDate': '2024-01-13',
#   'lastTicketingDateTime': '2024-01-13',
#   'numberOfBookableSeats': 7,
#   'itineraries': [{'duration': 'PT5H',
#     'segments': [{'departure': {'iataCode': 'EZE',
#        'terminal': 'A',
#        'at': '2024-01-20T04:00:00'},
#       'arrival': {'iataCode': 'LIM', 'at': '2024-01-20T07:00:00'},
#       'carrierCode': 'LA',
#       'number': '2376',
#       'aircraft': {'code': '320'},
#       'duration': 'PT5H',
#       'id': '1',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]},
#    {'duration': 'PT4H35M',
#     'segments': [{'departure': {'iataCode': 'LIM',
#        'at': '2024-01-25T12:05:00'},
#       'arrival': {'iataCode': 'EZE',
#        'terminal': 'A',
#        'at': '2024-01-25T18:40:00'},
#       'carrierCode': 'LA',
#       'number': '2369',
#       'aircraft': {'code': '320'},
#       'duration': 'PT4H35M',
#       'id': '60',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'PEN',
#    'total': '2370.45',
#    'base': '1697.96',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '2370.45',
#    'additionalServices': [{'amount': '326.13', 'type': 'CHECKED_BAGS'}]},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': False},
#   'validatingAirlineCodes': ['LA'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'PEN', 'total': '2370.45', 'base': '1697.96'},
#     'fareDetailsBySegment': [{'segmentId': '1',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'QHEQPZ6I',
#       'brandedFare': 'QP',
#       'brandedFareLabel': 'BASIC',
#       'class': 'Q',
#       'includedCheckedBags': {'quantity': 0},
#       'amenities': [{'description': 'FIRST EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'SECOND EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'THIRD BAG 23KG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CARRY ON HAND BAGGAGE',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'BASIC SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'PREMIUM SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGE BEFORE DEPARTURE',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]},
#      {'segmentId': '60',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'QHEQPZ6I',
#       'brandedFare': 'QP',
#       'brandedFareLabel': 'BASIC',
#       'class': 'Q',
#       'includedCheckedBags': {'quantity': 0},
#       'amenities': [{'description': 'FIRST EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'SECOND EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'THIRD BAG 23KG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CARRY ON HAND BAGGAGE',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'BASIC SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'PREMIUM SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGE BEFORE DEPARTURE',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '2',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'lastTicketingDate': '2024-01-13',
#   'lastTicketingDateTime': '2024-01-13',
#   'numberOfBookableSeats': 7,
#   'itineraries': [{'duration': 'PT5H',
#     'segments': [{'departure': {'iataCode': 'EZE',
#        'terminal': 'A',
#        'at': '2024-01-20T04:00:00'},
#       'arrival': {'iataCode': 'LIM', 'at': '2024-01-20T07:00:00'},
#       'carrierCode': 'LA',
#       'number': '2376',
#       'aircraft': {'code': '320'},
#       'duration': 'PT5H',
#       'id': '1',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]},
#    {'duration': 'PT4H35M',
#     'segments': [{'departure': {'iataCode': 'LIM',
#        'at': '2024-01-25T20:25:00'},
#       'arrival': {'iataCode': 'EZE',
#        'terminal': 'A',
#        'at': '2024-01-26T03:00:00'},
#       'carrierCode': 'LA',
#       'number': '2375',
#       'aircraft': {'code': '320'},
#       'duration': 'PT4H35M',
#       'id': '61',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'PEN',
#    'total': '2370.45',
#    'base': '1697.96',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '2370.45',
#    'additionalServices': [{'amount': '326.13', 'type': 'CHECKED_BAGS'}]},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': False},
#   'validatingAirlineCodes': ['LA'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'PEN', 'total': '2370.45', 'base': '1697.96'},
#     'fareDetailsBySegment': [{'segmentId': '1',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'QHEQPZ6I',
#       'brandedFare': 'QP',
#       'brandedFareLabel': 'BASIC',
#       'class': 'Q',
#       'includedCheckedBags': {'quantity': 0},
#       'amenities': [{'description': 'FIRST EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'SECOND EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'THIRD BAG 23KG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CARRY ON HAND BAGGAGE',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'BASIC SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'PREMIUM SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGE BEFORE DEPARTURE',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]},
#      {'segmentId': '61',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'QHEQPZ6I',
#       'brandedFare': 'QP',
#       'brandedFareLabel': 'BASIC',
#       'class': 'Q',
#       'includedCheckedBags': {'quantity': 0},
#       'amenities': [{'description': 'FIRST EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'SECOND EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'THIRD BAG 23KG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CARRY ON HAND BAGGAGE',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'BASIC SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'PREMIUM SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGE BEFORE DEPARTURE',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '3',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'lastTicketingDate': '2024-01-13',
#   'lastTicketingDateTime': '2024-01-13',
#   'numberOfBookableSeats': 7,
#   'itineraries': [{'duration': 'PT5H',
#     'segments': [{'departure': {'iataCode': 'EZE',
#        'terminal': 'A',
#        'at': '2024-01-20T19:35:00'},
#       'arrival': {'iataCode': 'LIM', 'at': '2024-01-20T22:35:00'},
#       'carrierCode': 'LA',
#       'number': '2368',
#       'aircraft': {'code': '320'},
#       'duration': 'PT5H',
#       'id': '2',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]},
#    {'duration': 'PT4H35M',
#     'segments': [{'departure': {'iataCode': 'LIM',
#        'at': '2024-01-25T12:05:00'},
#       'arrival': {'iataCode': 'EZE',
#        'terminal': 'A',
#        'at': '2024-01-25T18:40:00'},
#       'carrierCode': 'LA',
#       'number': '2369',
#       'aircraft': {'code': '320'},
#       'duration': 'PT4H35M',
#       'id': '60',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'PEN',
#    'total': '2370.45',
#    'base': '1697.96',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '2370.45',
#    'additionalServices': [{'amount': '326.13', 'type': 'CHECKED_BAGS'}]},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': False},
#   'validatingAirlineCodes': ['LA'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'PEN', 'total': '2370.45', 'base': '1697.96'},
#     'fareDetailsBySegment': [{'segmentId': '2',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'QHEQPZ6I',
#       'brandedFare': 'QP',
#       'brandedFareLabel': 'BASIC',
#       'class': 'Q',
#       'includedCheckedBags': {'quantity': 0},
#       'amenities': [{'description': 'FIRST EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'SECOND EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'THIRD BAG 23KG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CARRY ON HAND BAGGAGE',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'BASIC SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'PREMIUM SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGE BEFORE DEPARTURE',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]},
#      {'segmentId': '60',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'QHEQPZ6I',
#       'brandedFare': 'QP',
#       'brandedFareLabel': 'BASIC',
#       'class': 'Q',
#       'includedCheckedBags': {'quantity': 0},
#       'amenities': [{'description': 'FIRST EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'SECOND EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'THIRD BAG 23KG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CARRY ON HAND BAGGAGE',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'BASIC SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'PREMIUM SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGE BEFORE DEPARTURE',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '4',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'lastTicketingDate': '2024-01-13',
#   'lastTicketingDateTime': '2024-01-13',
#   'numberOfBookableSeats': 7,
#   'itineraries': [{'duration': 'PT5H',
#     'segments': [{'departure': {'iataCode': 'EZE',
#        'terminal': 'A',
#        'at': '2024-01-20T19:35:00'},
#       'arrival': {'iataCode': 'LIM', 'at': '2024-01-20T22:35:00'},
#       'carrierCode': 'LA',
#       'number': '2368',
#       'aircraft': {'code': '320'},
#       'duration': 'PT5H',
#       'id': '2',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]},
#    {'duration': 'PT4H35M',
#     'segments': [{'departure': {'iataCode': 'LIM',
#        'at': '2024-01-25T20:25:00'},
#       'arrival': {'iataCode': 'EZE',
#        'terminal': 'A',
#        'at': '2024-01-26T03:00:00'},
#       'carrierCode': 'LA',
#       'number': '2375',
#       'aircraft': {'code': '320'},
#       'duration': 'PT4H35M',
#       'id': '61',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'PEN',
#    'total': '2370.45',
#    'base': '1697.96',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '2370.45',
#    'additionalServices': [{'amount': '326.13', 'type': 'CHECKED_BAGS'}]},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': False},
#   'validatingAirlineCodes': ['LA'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'PEN', 'total': '2370.45', 'base': '1697.96'},
#     'fareDetailsBySegment': [{'segmentId': '2',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'QHEQPZ6I',
#       'brandedFare': 'QP',
#       'brandedFareLabel': 'BASIC',
#       'class': 'Q',
#       'includedCheckedBags': {'quantity': 0},
#       'amenities': [{'description': 'FIRST EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'SECOND EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'THIRD BAG 23KG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CARRY ON HAND BAGGAGE',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'BASIC SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'PREMIUM SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGE BEFORE DEPARTURE',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]},
#      {'segmentId': '61',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'QHEQPZ6I',
#       'brandedFare': 'QP',
#       'brandedFareLabel': 'BASIC',
#       'class': 'Q',
#       'includedCheckedBags': {'quantity': 0},
#       'amenities': [{'description': 'FIRST EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'SECOND EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'THIRD BAG 23KG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CARRY ON HAND BAGGAGE',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'BASIC SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'PREMIUM SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGE BEFORE DEPARTURE',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]},
#  {'type': 'flight-offer',
#   'id': '5',
#   'source': 'GDS',
#   'instantTicketingRequired': False,
#   'nonHomogeneous': False,
#   'oneWay': False,
#   'lastTicketingDate': '2024-01-13',
#   'lastTicketingDateTime': '2024-01-13',
#   'numberOfBookableSeats': 7,
#   'itineraries': [{'duration': 'PT5H',
#     'segments': [{'departure': {'iataCode': 'EZE',
#        'terminal': 'A',
#        'at': '2024-01-20T04:00:00'},
#       'arrival': {'iataCode': 'LIM', 'at': '2024-01-20T07:00:00'},
#       'carrierCode': 'LA',
#       'number': '2376',
#       'aircraft': {'code': '320'},
#       'duration': 'PT5H',
#       'id': '1',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]},
#    {'duration': 'PT8H2M',
#     'segments': [{'departure': {'iataCode': 'LIM',
#        'at': '2024-01-25T12:25:00'},
#       'arrival': {'iataCode': 'SCL',
#        'terminal': '2',
#        'at': '2024-01-25T18:05:00'},
#       'carrierCode': 'LA',
#       'number': '651',
#       'aircraft': {'code': '320'},
#       'operating': {'carrierCode': 'LA'},
#       'duration': 'PT3H40M',
#       'id': '40',
#       'numberOfStops': 0,
#       'blacklistedInEU': False},
#      {'departure': {'iataCode': 'SCL',
#        'terminal': '2',
#        'at': '2024-01-25T20:30:00'},
#       'arrival': {'iataCode': 'EZE',
#        'terminal': 'A',
#        'at': '2024-01-25T22:27:00'},
#       'carrierCode': 'LA',
#       'number': '471',
#       'aircraft': {'code': '320'},
#       'operating': {'carrierCode': 'LA'},
#       'duration': 'PT1H57M',
#       'id': '41',
#       'numberOfStops': 0,
#       'blacklistedInEU': False}]}],
#   'price': {'currency': 'PEN',
#    'total': '2418.47',
#    'base': '1697.96',
#    'fees': [{'amount': '0.00', 'type': 'SUPPLIER'},
#     {'amount': '0.00', 'type': 'TICKETING'}],
#    'grandTotal': '2418.47',
#    'additionalServices': [{'amount': '326.13', 'type': 'CHECKED_BAGS'}]},
#   'pricingOptions': {'fareType': ['PUBLISHED'],
#    'includedCheckedBagsOnly': False},
#   'validatingAirlineCodes': ['LA'],
#   'travelerPricings': [{'travelerId': '1',
#     'fareOption': 'STANDARD',
#     'travelerType': 'ADULT',
#     'price': {'currency': 'PEN', 'total': '2418.47', 'base': '1697.96'},
#     'fareDetailsBySegment': [{'segmentId': '1',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'QHEQPZ6I',
#       'brandedFare': 'QP',
#       'brandedFareLabel': 'BASIC',
#       'class': 'Q',
#       'includedCheckedBags': {'quantity': 0},
#       'amenities': [{'description': 'FIRST EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'SECOND EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'THIRD BAG 23KG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CARRY ON HAND BAGGAGE',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'BASIC SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'PREMIUM SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGE BEFORE DEPARTURE',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]},
#      {'segmentId': '40',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'QHEQPZ6I',
#       'brandedFare': 'QP',
#       'brandedFareLabel': 'BASIC',
#       'class': 'Q',
#       'includedCheckedBags': {'quantity': 0},
#       'amenities': [{'description': 'FIRST EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'SECOND EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'THIRD BAG 23KG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CARRY ON HAND BAGGAGE',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'BASIC SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'PREMIUM SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGE BEFORE DEPARTURE',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]},
#      {'segmentId': '41',
#       'cabin': 'ECONOMY',
#       'fareBasis': 'QHEQPZ6I',
#       'brandedFare': 'QP',
#       'brandedFareLabel': 'BASIC',
#       'class': 'Q',
#       'includedCheckedBags': {'quantity': 0},
#       'amenities': [{'description': 'FIRST EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'SECOND EXCESS BAG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'THIRD BAG 23KG',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CARRY ON HAND BAGGAGE',
#         'isChargeable': True,
#         'amenityType': 'BAGGAGE',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'BASIC SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'PREMIUM SEAT RESERVATION',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}},
#        {'description': 'CHANGE BEFORE DEPARTURE',
#         'isChargeable': True,
#         'amenityType': 'BRANDED_FARES',
#         'amenityProvider': {'name': 'BrandedFare'}}]}]}]}]

# %%
#Visualizamos nuestra formato JSON en un Data Frame
df_vuelos
# Out:
#            type id source  instantTicketingRequired  nonHomogeneous  oneWay  \
# 0  flight-offer  1    GDS                     False           False   False
# 1  flight-offer  2    GDS                     False           False   False
# 2  flight-offer  3    GDS                     False           False   False
# 3  flight-offer  4    GDS                     False           False   False
# 4  flight-offer  5    GDS                     False           False   False
#
#   lastTicketingDate lastTicketingDateTime  numberOfBookableSeats  \
# 0        2024-01-13            2024-01-13                      7
# 1        2024-01-13            2024-01-13                      7
# 2        2024-01-13            2024-01-13                      7
# 3        2024-01-13            2024-01-13                      7
# 4        2024-01-13            2024-01-13                      7
#
#                                          itineraries validatingAirlineCodes  \
# 0  [{'duration': 'PT5H', 'segments': [{'departure...                   [LA]
# 1  [{'duration': 'PT5H', 'segments': [{'departure...                   [LA]
# 2  [{'duration': 'PT5H', 'segments': [{'departure...                   [LA]
# 3  [{'duration': 'PT5H', 'segments': [{'departure...                   [LA]
# 4  [{'duration': 'PT5H', 'segments': [{'departure...                   [LA]
#
#                                     travelerPricings price.currency  \
# 0  [{'travelerId': '1', 'fareOption': 'STANDARD',...            PEN
# 1  [{'travelerId': '1', 'fareOption': 'STANDARD',...            PEN
# 2  [{'travelerId': '1', 'fareOption': 'STANDARD',...            PEN
# 3  [{'travelerId': '1', 'fareOption': 'STANDARD',...            PEN
# 4  [{'travelerId': '1', 'fareOption': 'STANDARD',...            PEN
#
#   price.total price.base                                         price.fees  \
# 0     2370.45    1697.96  [{'amount': '0.00', 'type': 'SUPPLIER'}, {'amo...
# 1     2370.45    1697.96  [{'amount': '0.00', 'type': 'SUPPLIER'}, {'amo...
# 2     2370.45    1697.96  [{'amount': '0.00', 'type': 'SUPPLIER'}, {'amo...
# 3     2370.45    1697.96  [{'amount': '0.00', 'type': 'SUPPLIER'}, {'amo...
# 4     2418.47    1697.96  [{'amount': '0.00', 'type': 'SUPPLIER'}, {'amo...
#
#   price.grandTotal                        price.additionalServices  \
# 0          2370.45  [{'amount': '326.13', 'type': 'CHECKED_BAGS'}]
# 1          2370.45  [{'amount': '326.13', 'type': 'CHECKED_BAGS'}]
# 2          2370.45  [{'amount': '326.13', 'type': 'CHECKED_BAGS'}]
# 3          2370.45  [{'amount': '326.13', 'type': 'CHECKED_BAGS'}]
# 4          2418.47  [{'amount': '326.13', 'type': 'CHECKED_BAGS'}]
#
#   pricingOptions.fareType  pricingOptions.includedCheckedBagsOnly
# 0             [PUBLISHED]                                   False
# 1             [PUBLISHED]                                   False
# 2             [PUBLISHED]                                   False
# 3             [PUBLISHED]                                   False
# 4             [PUBLISHED]                                   False
